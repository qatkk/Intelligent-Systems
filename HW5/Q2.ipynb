# %% [markdown]
# ###What are our states ?
#
# full , not full, full-full, minimum
#
# ### What are our actions ?
# full-full : end contract r-> 0 (maximum capacity of 25)
# full : end contract r-> 0, buy space r -> -2 per customer
# not full : end contract r-> 0, new contract r-> 10 per costumer, lend space r-> 2 per customer
# minimum : new contract -> 10 per customer (already lent 5 of it's capacity )
#
# ### Description
# minimum capacity for each company is 15 and maximum is 25
# no company can lend more than 5 space to another
# number of customer = 20 without buying space
#
# we've got 4 states and actions at each state are shown in the above table.
#
# another variable at each state is a tuple of how many new contract request and how many end contract requests we have.
#
# newContractFirstCompany  = $$\frac{3^n} {n!} * e ^{-3}$$
# endContractFirstCompany  = $$\frac{3^n} {n!} * e ^{-3}$$
# newContractSecondCompany  = $$\frac{4^n} {n!} * e ^{-4}$$
# endContractSecondCompany  = $$\frac{2^n} {n!} * e ^{-2}$$
#
#
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
def numberOfCustomers(lambda)

# %%
# initialize states 
nS = 441 # 21 from 0 to 20 for each company  11 will be each having one customer 
nA = 2
# acts lend space(0), buy space(1)
# rewards are +2 , -2 
values = np.zeros((21, 21))
policy = np.zeros((21, 21))
rewards = {0: 2, 1:-2}
